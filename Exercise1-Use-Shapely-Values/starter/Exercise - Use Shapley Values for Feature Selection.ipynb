# %%
# !pip install xgboost
# !pip install shap
import xgboost
from sklearn.datasets import load_breast_cancer
import shap
import pandas as pd

# Load the Breast Cancer dataset
# We will train a classifier to determine whether a given breast cancer falls into one of three categories.
bc_data = load_breast_cancer()

# Set the features and targets of the wine dataset
X = 
y = 

# Establish the baseline sample and appropriate index
X100 = shap.utils.sample(X, 100)
sample_ind = 20
xg_boost_model = xgboost.XGBRegressor(n_estimators=10, max_depth=3).fit(X, y)

# explain the model with SHAP values
explainer_xgb = shap.Explainer(xg_boost_model, X100)
shap_values_xgb = explainer_xgb(X)

shap.plots.waterfall(shap_values_xgb[sample_ind])
# Out:
# Requirement already satisfied: xgboost in /opt/venv/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: nvidia-nccl-cu12 in /opt/venv/lib/python3.10/site-packages (from xgboost) (2.22.3)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.10/site-packages (from xgboost) (2.0.1)
# Requirement already satisfied: scipy in /opt/venv/lib/python3.10/site-packages (from xgboost) (1.14.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: shap in /opt/venv/lib/python3.10/site-packages (0.46.0)
# Requirement already satisfied: cloudpickle in /opt/venv/lib/python3.10/site-packages (from shap) (3.0.0)
# Requirement already satisfied: pandas in /opt/venv/lib/python3.10/site-packages (from shap) (2.2.2)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.10/site-packages (from shap) (2.0.1)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.10/site-packages (from shap) (1.5.1)
# Requirement already satisfied: packaging>20.9 in /opt/venv/lib/python3.10/site-packages (from shap) (24.1)
# Requirement already satisfied: scipy in /opt/venv/lib/python3.10/site-packages (from shap) (1.14.0)
# Requirement already satisfied: numba in /opt/venv/lib/python3.10/site-packages (from shap) (0.60.0)
# Requirement already satisfied: slicer==0.0.8 in /opt/venv/lib/python3.10/site-packages (from shap) (0.0.8)
# Requirement already satisfied: tqdm>=4.27.0 in /opt/venv/lib/python3.10/site-packages (from shap) (4.66.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/venv/lib/python3.10/site-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.10/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.10/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/venv/lib/python3.10/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/venv/lib/python3.10/site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/venv/lib/python3.10/site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <b> Given the plot shown above, list the most important features for our breast cancer classification model: </b>
